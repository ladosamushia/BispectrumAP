# %%
using DelimitedFiles
using Plots

# %%
pk1s = readdlm(raw"camb_67273130_matterpower_z0.5_0050_smooth.mpeg");
pk1 = readdlm(raw"camb_67273130_matterpower_z0.5_0050.mpeg");
pk2s = readdlm(raw"camb_67773070_matterpower_z0.5_0060_smooth.mpeg");
pk2 = readdlm(raw"camb_67773070_matterpower_z0.5_0060.mpeg");

# %%
plot(pk1[:,1], pk1[:,2]./pk1s/1800, dpi=500, ylims=(0.8,1.2))
plot!(pk2[:,1], pk2[:,2]./pk2s/1840)

# %%
plot(pk1[:,2], dpi=500)
plot!(1500*pk1s)
